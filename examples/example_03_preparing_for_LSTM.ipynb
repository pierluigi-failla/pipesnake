# %% [markdown]
# # `LSTMPacker`
#
# A simple example about using `LSTMPacker`

# %%
# if you cloned the repository you can do:
import sys
sys.path.append('../')

import logging
import pandas

logging.getLogger().setLevel(logging.DEBUG)

# %% [markdown]
# # Load some data
#
# More dataset are available here: https://archive.ics.uci.edu/ml/datasets.html
#
# _Lichman, M. (2013). UCI Machine Learning Repository [http://archive.ics.uci.edu/ml]. Irvine, CA: University of California, School of Information and Computer Science._

# %%
df = pandas.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/00374/energydata_complete.csv')
df.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4    ...             T9   RH_9     T_out  \
# 0  19.79  44.730000  19.000000    ...      17.033333  45.53  6.600000
# 1  19.79  44.790000  19.000000    ...      17.066667  45.56  6.483333
# 2  19.79  44.933333  18.926667    ...      17.000000  45.50  6.366667
# 3  19.79  45.000000  18.890000    ...      17.000000  45.40  6.250000
# 4  19.79  45.000000  18.890000    ...      17.000000  45.40  6.133333
#
#    Press_mm_hg  RH_out  Windspeed  Visibility  Tdewpoint        rv1        rv2
# 0        733.5    92.0   7.000000   63.000000        5.3  13.275433  13.275433
# 1        733.6    92.0   6.666667   59.166667        5.2  18.606195  18.606195
# 2        733.7    92.0   6.333333   55.333333        5.1  28.642668  28.642668
# 3        733.8    92.0   6.000000   51.500000        5.0  45.410389  45.410389
# 4        733.9    92.0   5.666667   47.666667        4.9  10.084097  10.084097
#
# [5 rows x 29 columns]

# %%
df.columns
# Out:
# Index(['date', 'Appliances', 'lights', 'T1', 'RH_1', 'T2', 'RH_2', 'T3',
#        'RH_3', 'T4', 'RH_4', 'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8',
#        'RH_8', 'T9', 'RH_9', 'T_out', 'Press_mm_hg', 'RH_out', 'Windspeed',
#        'Visibility', 'Tdewpoint', 'rv1', 'rv2'],
#       dtype='object')

# %% [markdown]
# # Data Raw
#
# I'm going to define my target as the total energy used in `Wh` summing `Appliances` and `lights`. The data set will be composed by all columns excluded `date` (dataset is already sorted), `rv1` and `rv2` (see here for more details: https://archive.ics.uci.edu/ml/datasets/Appliances+energy+prediction)

# %%
x = df[['T1', 'RH_1', 'T2', 'RH_2', 'T3',
       'RH_3', 'T4', 'RH_4', 'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8',
       'RH_8', 'T9', 'RH_9', 'T_out', 'Press_mm_hg', 'RH_out', 'Windspeed',
       'Visibility', 'Tdewpoint']]
y = (df['Appliances'] + df['lights']).to_frame()

# %% [markdown]
# # Create a preprocessing pipeline using `pipesnake` for LSTM

# %%
from pipesnake.pipe import SeriesPipe
from pipesnake.transformers.dropper import DropDuplicates
from pipesnake.transformers.imputer import KnnImputer
from pipesnake.transformers.misc import ColumnRenamer
from pipesnake.transformers.scaler import MadScaler
from pipesnake.transformers.scaler import UnitLenghtScaler

# %%
my_pipe = SeriesPipe(transformers=[
    ColumnRenamer(),  # nomalize columns names
    DropDuplicates(),  # drop duplicated rows and cols
    KnnImputer(x_cols='all'),  # impute missing values
    MadScaler(x_cols='all', y_cols='all'),  # scale by feature (cols)
    UnitLenghtScaler(x_cols='all'),  # scale by feature vector (rows)
])

# %%
x_new, y_new = my_pipe.fit_transform(x, y)
# Out:
# DEBUG:root:[series_pipe_95c4] : fitting...
# DEBUG:root:Function: timed before Memory: 108.81 MB
# INFO:root:[series_pipe_95c4] : fitting x...
# INFO:root:[series_pipe_95c4] : -> column_renamer_3a21
# DEBUG:root:[column_renamer_3a21] : x new column names: ['x_00', 'x_01', 'x_02', 'x_03', 'x_04', 'x_05', 'x_06', 'x_07', 'x_08', 'x_09', 'x_10', 'x_11', 'x_12', 'x_13', 'x_14', 'x_15', 'x_16', 'x_17', 'x_18', 'x_19', 'x_20', 'x_21', 'x_22', 'x_23']
# INFO:root:[series_pipe_95c4] : -> drop_duplicates_eb03
# DEBUG:root:[drop_duplicates_eb03] : x shape: (19735, 24)
# DEBUG:root:[drop_duplicates_eb03] :   shape: (19735, 24)
# INFO:root:[series_pipe_95c4] : -> knn_imputer_f7a6
# DEBUG:root:[knn_imputer_f7a6] : x_cols: ['x_00', 'x_01', 'x_02', 'x_03', 'x_04', 'x_05', 'x_06', 'x_07', 'x_08', 'x_09', 'x_10', 'x_11', 'x_12', 'x_13', 'x_14', 'x_15', 'x_16', 'x_17', 'x_18', 'x_19', 'x_20', 'x_21', 'x_22', 'x_23']
# INFO:root:[knn_imputer_f7a6] : current shape: (19735, 24)
# DEBUG:root:[category2_number_5f5d] : fitting...
# DEBUG:root:[category2_number_5f5d] : x_cols: []
# WARNING:root:[category2_number_5f5d] : input is not a Pandas DataFrame, instead got <class 'NoneType'>
# DEBUG:root:[category2_number_5f5d] : transforming...
# DEBUG:root:[category2_number_5f5d] : x category to number: {}
# WARNING:root:[category2_number_5f5d] : input is not a Pandas DataFrame, instead got <class 'NoneType'>
# DEBUG:root:[knn_imputer_f7a6] : fitting imputing_model for column: x_00 x_train.shape=(19735, 23) y_train.shape=(19735,)
# DEBUG:root:[knn_imputer_f7a6] : fitting imputing_model for column: x_01 x_train.shape=(19735, 23) y_train.shape=(19735,)
# DEBUG:root:[knn_imputer_f7a6] : fitting imputing_model for column: x_02 x_train.shape=(19735, 23) y_train.shape=(19735,)
# DEBUG:root:[knn_imputer_f7a6] : fitting imputing_model for column: x_03 x_train.shape=(19735, 23) y_train.shape=(19735,)
# DEBUG:root:[knn_imputer_f7a6] : fitting imputing_model for column: x_04 x_train.shape=(19735, 23) y_train.shape=(19735,)
# DEBUG:root:[knn_imputer_f7a6] : fitting imputing_model for column: x_05 x_train.shape=(19735, 23) y_train.shape=(19735,)
# DEBUG:root:[knn_imputer_f7a6] : fitting imputing_model for column: x_06 x_train.shape=(19735, 23) y_train.shape=(19735,)
# DEBUG:root:[knn_imputer_f7a6] : fitting imputing_model for column: x_07 x_train.shape=(19735, 23) y_train.shape=(19735,)
# DEBUG:root:[knn_imputer_f7a6] : fitting imputing_model for column: x_08 x_train.shape=(19735, 23) y_train.shape=(19735,)
# DEBUG:root:[knn_imputer_f7a6] : fitting imputing_model for column: x_09 x_train.shape=(19735, 23) y_train.shape=(19735,)
# DEBUG:root:[knn_imputer_f7a6] : fitting imputing_model for column: x_10 x_train.shape=(19735, 23) y_train.shape=(19735,)
# DEBUG:root:[knn_imputer_f7a6] : fitting imputing_model for column: x_11 x_train.shape=(19735, 23) y_train.shape=(19735,)
# DEBUG:root:[knn_imputer_f7a6] : fitting imputing_model for column: x_12 x_train.shape=(19735, 23) y_train.shape=(19735,)
# DEBUG:root:[knn_imputer_f7a6] : fitting imputing_model for column: x_13 x_train.shape=(19735, 23) y_train.shape=(19735,)
# DEBUG:root:[knn_imputer_f7a6] : fitting imputing_model for column: x_14 x_train.shape=(19735, 23) y_train.shape=(19735,)
# DEBUG:root:[knn_imputer_f7a6] : fitting imputing_model for column: x_15 x_train.shape=(19735, 23) y_train.shape=(19735,)
# DEBUG:root:[knn_imputer_f7a6] : fitting imputing_model for column: x_16 x_train.shape=(19735, 23) y_train.shape=(19735,)
# DEBUG:root:[knn_imputer_f7a6] : fitting imputing_model for column: x_17 x_train.shape=(19735, 23) y_train.shape=(19735,)
# DEBUG:root:[knn_imputer_f7a6] : fitting imputing_model for column: x_18 x_train.shape=(19735, 23) y_train.shape=(19735,)
# DEBUG:root:[knn_imputer_f7a6] : fitting imputing_model for column: x_19 x_train.shape=(19735, 23) y_train.shape=(19735,)
# DEBUG:root:[knn_imputer_f7a6] : fitting imputing_model for column: x_20 x_train.shape=(19735, 23) y_train.shape=(19735,)
# DEBUG:root:[knn_imputer_f7a6] : fitting imputing_model for column: x_21 x_train.shape=(19735, 23) y_train.shape=(19735,)
# DEBUG:root:[knn_imputer_f7a6] : fitting imputing_model for column: x_22 x_train.shape=(19735, 23) y_train.shape=(19735,)
# DEBUG:root:[knn_imputer_f7a6] : fitting imputing_model for column: x_23 x_train.shape=(19735, 23) y_train.shape=(19735,)
# DEBUG:root:[category2_number_5f5d] : transforming...
# DEBUG:root:[category2_number_5f5d] : x category to number: {}
# WARNING:root:[category2_number_5f5d] : input is not a Pandas DataFrame, instead got <class 'NoneType'>
# DEBUG:root:[category2_number_5f5d] : inverse transforming...
# DEBUG:root:[category2_number_5f5d] : x number to category: {}
# WARNING:root:[category2_number_5f5d] : input is not a Pandas DataFrame, instead got <class 'NoneType'>
# INFO:root:[series_pipe_95c4] : -> mad_scaler_68d
# DEBUG:root:[mad_scaler_68d] : x_cols: ['x_00', 'x_01', 'x_02', 'x_03', 'x_04', 'x_05', 'x_06', 'x_07', 'x_08', 'x_09', 'x_10', 'x_11', 'x_12', 'x_13', 'x_14', 'x_15', 'x_16', 'x_17', 'x_18', 'x_19', 'x_20', 'x_21', 'x_22', 'x_23']
# INFO:root:[series_pipe_95c4] : -> unit_lenght_scaler_148
# DEBUG:root:[unit_lenght_scaler_148] : x_cols: ['x_00', 'x_01', 'x_02', 'x_03', 'x_04', 'x_05', 'x_06', 'x_07', 'x_08', 'x_09', 'x_10', 'x_11', 'x_12', 'x_13', 'x_14', 'x_15', 'x_16', 'x_17', 'x_18', 'x_19', 'x_20', 'x_21', 'x_22', 'x_23']
# DEBUG:root:Function: fit_x: 6.98 sec
# DEBUG:root:Function: timed after Memory: 314.66 MB
# DEBUG:root:Function: timed before Memory: 314.66 MB
# INFO:root:[series_pipe_95c4] : fitting y...
# INFO:root:[series_pipe_95c4] : -> column_renamer_3a21
# DEBUG:root:[column_renamer_3a21] : y new column names: ['y_0']
# INFO:root:[series_pipe_95c4] : -> drop_duplicates_eb03
# DEBUG:root:[drop_duplicates_eb03] : y shape: (19735, 1)
# DEBUG:root:[drop_duplicates_eb03] :   shape: (19735, 1)
# INFO:root:[series_pipe_95c4] : -> knn_imputer_f7a6
# DEBUG:root:[knn_imputer_f7a6] : y_cols: []
# INFO:root:[series_pipe_95c4] : -> mad_scaler_68d
# DEBUG:root:[mad_scaler_68d] : y_cols: ['y_0']
# INFO:root:[series_pipe_95c4] : -> unit_lenght_scaler_148
# DEBUG:root:[unit_lenght_scaler_148] : y_cols: []
# DEBUG:root:Function: fit_y: 0.03 sec
# DEBUG:root:Function: timed after Memory: 314.90 MB
# DEBUG:root:[series_pipe_95c4] : transforming...
# DEBUG:root:Function: timed before Memory: 314.90 MB
# INFO:root:[series_pipe_95c4] : transforming x...
# INFO:root:[series_pipe_95c4] : -> column_renamer_3a21
# DEBUG:root:[column_renamer_3a21] : x new column names: ['x_00', 'x_01', 'x_02', 'x_03', 'x_04', 'x_05', 'x_06', 'x_07', 'x_08', 'x_09', 'x_10', 'x_11', 'x_12', 'x_13', 'x_14', 'x_15', 'x_16', 'x_17', 'x_18', 'x_19', 'x_20', 'x_21', 'x_22', 'x_23']
# INFO:root:[series_pipe_95c4] : -> drop_duplicates_eb03
# DEBUG:root:[drop_duplicates_eb03] : x shape: (19735, 24)
# DEBUG:root:[drop_duplicates_eb03] :   shape: (19735, 24)
# INFO:root:[series_pipe_95c4] : -> knn_imputer_f7a6
# DEBUG:root:[category2_number_5f5d] : transforming...
# DEBUG:root:[category2_number_5f5d] : x category to number: {}
# WARNING:root:[category2_number_5f5d] : input is not a Pandas DataFrame, instead got <class 'NoneType'>
# DEBUG:root:[category2_number_5f5d] : inverse transforming...
# DEBUG:root:[category2_number_5f5d] : x number to category: {}
# WARNING:root:[category2_number_5f5d] : input is not a Pandas DataFrame, instead got <class 'NoneType'>
# INFO:root:[series_pipe_95c4] : -> mad_scaler_68d
# INFO:root:[series_pipe_95c4] : -> unit_lenght_scaler_148
# DEBUG:root:Function: transform_x: 5.80 sec
# DEBUG:root:Function: timed after Memory: 317.73 MB
# DEBUG:root:Function: timed before Memory: 317.73 MB
# INFO:root:[series_pipe_95c4] : transforming y...
# INFO:root:[series_pipe_95c4] : -> column_renamer_3a21
# DEBUG:root:[column_renamer_3a21] : y new column names: ['y_0']
# INFO:root:[series_pipe_95c4] : -> drop_duplicates_eb03
# DEBUG:root:[drop_duplicates_eb03] : y shape: (19735, 1)
# DEBUG:root:[drop_duplicates_eb03] :   shape: (19735, 1)
# INFO:root:[series_pipe_95c4] : -> knn_imputer_f7a6
# INFO:root:[series_pipe_95c4] : -> mad_scaler_68d
# INFO:root:[series_pipe_95c4] : -> unit_lenght_scaler_148
# DEBUG:root:Function: transform_y: 0.02 sec
# DEBUG:root:Function: timed after Memory: 318.50 MB

# %%
x_new.head()
# Out:
#        x_00      x_01      x_02      x_03      x_04      x_05      x_06  \
# 0 -0.164230  0.293406 -0.056150  0.160984 -0.173926  0.276208 -0.123446
# 1 -0.168801  0.267261 -0.057712  0.162861 -0.178766  0.286642 -0.126882
# 2 -0.172730  0.258195 -0.059055  0.162869 -0.182927  0.300029 -0.135548
# 3 -0.175660  0.253353 -0.060057  0.164161 -0.186031  0.308296 -0.140752
# 4 -0.177921  0.267289 -0.060830  0.163834 -0.188425  0.312264 -0.142564
#
#        x_07      x_08      x_09    ...         x_14      x_15      x_16  \
# 0  0.238780 -0.181978  0.116963    ...    -0.298576  0.182212 -0.173692
# 1  0.260008 -0.187042  0.120218    ...    -0.306885  0.186230 -0.176001
# 2  0.262468 -0.191395  0.120801    ...    -0.314027  0.186649 -0.185265
# 3  0.260981 -0.194642  0.122851    ...    -0.327544  0.185634 -0.188408
# 4  0.257361 -0.194192  0.124432    ...    -0.331759  0.188023 -0.190833
#
#        x_17      x_18      x_19      x_20      x_21      x_22      x_23
# 0  0.162597 -0.009017 -0.456834  0.081433  0.202389  0.317786  0.066402
# 1  0.168205 -0.012682 -0.467470  0.083699  0.187219  0.272192  0.064593
# 2  0.169903 -0.016471 -0.476224  0.085647  0.170290  0.222821  0.062355
# 3  0.169030 -0.020304 -0.482142  0.087100  0.151532  0.169951  0.059609
# 4  0.171205 -0.024164 -0.486156  0.088221  0.131556  0.114759  0.056522
#
# [5 rows x 24 columns]

# %%
y_new.head()
# Out:
#         y_0
# 0  0.159805
# 1  0.159805
# 2  0.106537
# 3  0.159805
# 4  0.213073

# %%
_, y_org = my_pipe.inverse_transform(x=None, y=y_new)
# Out:
# DEBUG:root:[series_pipe_95c4] : inverse transforming...
# WARNING:root:[series_pipe_95c4] : input is not a Pandas DataFrame, instead got <class 'NoneType'>
# DEBUG:root:Function: timed before Memory: 318.09 MB
# INFO:root:[series_pipe_95c4] : inverse transforming y...
# INFO:root:[series_pipe_95c4] : -> unit_lenght_scaler_148
# INFO:root:[series_pipe_95c4] : -> mad_scaler_68d
# INFO:root:[series_pipe_95c4] : -> knn_imputer_f7a6
# WARNING:root:[knn_imputer_f7a6] : removing nan cols y is not invertible as transformation
# INFO:root:[series_pipe_95c4] : -> drop_duplicates_eb03
# WARNING:root:[drop_duplicates_eb03] : removing y duplicates is not invertible as transformation
# INFO:root:[series_pipe_95c4] : -> column_renamer_3a21
# DEBUG:root:[column_renamer_3a21] : y original column names: [0]
# DEBUG:root:Function: inverse_transform_y: 0.02 sec
# DEBUG:root:Function: timed after Memory: 318.09 MB

# %%
y_org.head()
# Out:
#        0
# 0   90.0
# 1   90.0
# 2   80.0
# 3   90.0
# 4  100.0

# %%
from pipesnake.transformers.misc import ToNumpy
from pipesnake.transformers.deeplearning import LSTMPacker

my_pipe.extend([
    ToNumpy(),  # returns x and y as numpy matrix
    LSTMPacker(sequence_len=5),
])

# %%
x_new, y_new = my_pipe.fit_transform(x, y)
# Out:
# DEBUG:root:[series_pipe_95c4] : fitting...
# DEBUG:root:Function: timed before Memory: 318.12 MB
# INFO:root:[series_pipe_95c4] : fitting x...
# INFO:root:[series_pipe_95c4] : -> column_renamer_3a21
# DEBUG:root:[column_renamer_3a21] : x new column names: ['x_00', 'x_01', 'x_02', 'x_03', 'x_04', 'x_05', 'x_06', 'x_07', 'x_08', 'x_09', 'x_10', 'x_11', 'x_12', 'x_13', 'x_14', 'x_15', 'x_16', 'x_17', 'x_18', 'x_19', 'x_20', 'x_21', 'x_22', 'x_23']
# INFO:root:[series_pipe_95c4] : -> drop_duplicates_eb03
# DEBUG:root:[drop_duplicates_eb03] : x shape: (19735, 24)
# DEBUG:root:[drop_duplicates_eb03] :   shape: (19735, 24)
# INFO:root:[series_pipe_95c4] : -> knn_imputer_f7a6
# DEBUG:root:[knn_imputer_f7a6] : x_cols: ['x_00', 'x_01', 'x_02', 'x_03', 'x_04', 'x_05', 'x_06', 'x_07', 'x_08', 'x_09', 'x_10', 'x_11', 'x_12', 'x_13', 'x_14', 'x_15', 'x_16', 'x_17', 'x_18', 'x_19', 'x_20', 'x_21', 'x_22', 'x_23']
# INFO:root:[knn_imputer_f7a6] : current shape: (19735, 24)
# DEBUG:root:[category2_number_28ac] : fitting...
# DEBUG:root:[category2_number_28ac] : x_cols: []
# WARNING:root:[category2_number_28ac] : input is not a Pandas DataFrame, instead got <class 'NoneType'>
# DEBUG:root:[category2_number_28ac] : transforming...
# DEBUG:root:[category2_number_28ac] : x category to number: {}
# WARNING:root:[category2_number_28ac] : input is not a Pandas DataFrame, instead got <class 'NoneType'>
# DEBUG:root:[knn_imputer_f7a6] : fitting imputing_model for column: x_00 x_train.shape=(19735, 23) y_train.shape=(19735,)
# DEBUG:root:[knn_imputer_f7a6] : fitting imputing_model for column: x_01 x_train.shape=(19735, 23) y_train.shape=(19735,)
# DEBUG:root:[knn_imputer_f7a6] : fitting imputing_model for column: x_02 x_train.shape=(19735, 23) y_train.shape=(19735,)
# DEBUG:root:[knn_imputer_f7a6] : fitting imputing_model for column: x_03 x_train.shape=(19735, 23) y_train.shape=(19735,)
# DEBUG:root:[knn_imputer_f7a6] : fitting imputing_model for column: x_04 x_train.shape=(19735, 23) y_train.shape=(19735,)
# DEBUG:root:[knn_imputer_f7a6] : fitting imputing_model for column: x_05 x_train.shape=(19735, 23) y_train.shape=(19735,)
# DEBUG:root:[knn_imputer_f7a6] : fitting imputing_model for column: x_06 x_train.shape=(19735, 23) y_train.shape=(19735,)
# DEBUG:root:[knn_imputer_f7a6] : fitting imputing_model for column: x_07 x_train.shape=(19735, 23) y_train.shape=(19735,)
# DEBUG:root:[knn_imputer_f7a6] : fitting imputing_model for column: x_08 x_train.shape=(19735, 23) y_train.shape=(19735,)
# DEBUG:root:[knn_imputer_f7a6] : fitting imputing_model for column: x_09 x_train.shape=(19735, 23) y_train.shape=(19735,)
# DEBUG:root:[knn_imputer_f7a6] : fitting imputing_model for column: x_10 x_train.shape=(19735, 23) y_train.shape=(19735,)
# DEBUG:root:[knn_imputer_f7a6] : fitting imputing_model for column: x_11 x_train.shape=(19735, 23) y_train.shape=(19735,)
# DEBUG:root:[knn_imputer_f7a6] : fitting imputing_model for column: x_12 x_train.shape=(19735, 23) y_train.shape=(19735,)
# DEBUG:root:[knn_imputer_f7a6] : fitting imputing_model for column: x_13 x_train.shape=(19735, 23) y_train.shape=(19735,)
# DEBUG:root:[knn_imputer_f7a6] : fitting imputing_model for column: x_14 x_train.shape=(19735, 23) y_train.shape=(19735,)
# DEBUG:root:[knn_imputer_f7a6] : fitting imputing_model for column: x_15 x_train.shape=(19735, 23) y_train.shape=(19735,)
# DEBUG:root:[knn_imputer_f7a6] : fitting imputing_model for column: x_16 x_train.shape=(19735, 23) y_train.shape=(19735,)
# DEBUG:root:[knn_imputer_f7a6] : fitting imputing_model for column: x_17 x_train.shape=(19735, 23) y_train.shape=(19735,)
# DEBUG:root:[knn_imputer_f7a6] : fitting imputing_model for column: x_18 x_train.shape=(19735, 23) y_train.shape=(19735,)
# DEBUG:root:[knn_imputer_f7a6] : fitting imputing_model for column: x_19 x_train.shape=(19735, 23) y_train.shape=(19735,)
# DEBUG:root:[knn_imputer_f7a6] : fitting imputing_model for column: x_20 x_train.shape=(19735, 23) y_train.shape=(19735,)
# DEBUG:root:[knn_imputer_f7a6] : fitting imputing_model for column: x_21 x_train.shape=(19735, 23) y_train.shape=(19735,)
# DEBUG:root:[knn_imputer_f7a6] : fitting imputing_model for column: x_22 x_train.shape=(19735, 23) y_train.shape=(19735,)
# DEBUG:root:[knn_imputer_f7a6] : fitting imputing_model for column: x_23 x_train.shape=(19735, 23) y_train.shape=(19735,)
# DEBUG:root:[category2_number_28ac] : transforming...
# DEBUG:root:[category2_number_28ac] : x category to number: {}
# WARNING:root:[category2_number_28ac] : input is not a Pandas DataFrame, instead got <class 'NoneType'>
# DEBUG:root:[category2_number_28ac] : inverse transforming...
# DEBUG:root:[category2_number_28ac] : x number to category: {}
# WARNING:root:[category2_number_28ac] : input is not a Pandas DataFrame, instead got <class 'NoneType'>
# INFO:root:[series_pipe_95c4] : -> mad_scaler_68d
# DEBUG:root:[mad_scaler_68d] : x_cols: ['x_00', 'x_01', 'x_02', 'x_03', 'x_04', 'x_05', 'x_06', 'x_07', 'x_08', 'x_09', 'x_10', 'x_11', 'x_12', 'x_13', 'x_14', 'x_15', 'x_16', 'x_17', 'x_18', 'x_19', 'x_20', 'x_21', 'x_22', 'x_23']
# INFO:root:[series_pipe_95c4] : -> unit_lenght_scaler_148
# DEBUG:root:[unit_lenght_scaler_148] : x_cols: ['x_00', 'x_01', 'x_02', 'x_03', 'x_04', 'x_05', 'x_06', 'x_07', 'x_08', 'x_09', 'x_10', 'x_11', 'x_12', 'x_13', 'x_14', 'x_15', 'x_16', 'x_17', 'x_18', 'x_19', 'x_20', 'x_21', 'x_22', 'x_23']
# INFO:root:[series_pipe_95c4] : -> to_numpy_4ab9
# INFO:root:[series_pipe_95c4] : -> lstm_packer_192e
# DEBUG:root:Function: fit_x: 7.49 sec
# DEBUG:root:Function: timed after Memory: 327.56 MB
# DEBUG:root:Function: timed before Memory: 327.56 MB
# INFO:root:[series_pipe_95c4] : fitting y...
# INFO:root:[series_pipe_95c4] : -> column_renamer_3a21
# DEBUG:root:[column_renamer_3a21] : y new column names: ['y_0']
# INFO:root:[series_pipe_95c4] : -> drop_duplicates_eb03
# DEBUG:root:[drop_duplicates_eb03] : y shape: (19735, 1)
# DEBUG:root:[drop_duplicates_eb03] :   shape: (19735, 1)
# INFO:root:[series_pipe_95c4] : -> knn_imputer_f7a6
# DEBUG:root:[knn_imputer_f7a6] : y_cols: []
# INFO:root:[series_pipe_95c4] : -> mad_scaler_68d
# DEBUG:root:[mad_scaler_68d] : y_cols: ['y_0']
# INFO:root:[series_pipe_95c4] : -> unit_lenght_scaler_148
# DEBUG:root:[unit_lenght_scaler_148] : y_cols: []
# INFO:root:[series_pipe_95c4] : -> to_numpy_4ab9
# INFO:root:[series_pipe_95c4] : -> lstm_packer_192e
# DEBUG:root:Function: fit_y: 0.03 sec
# DEBUG:root:Function: timed after Memory: 328.21 MB
# DEBUG:root:[series_pipe_95c4] : transforming...
# DEBUG:root:Function: timed before Memory: 328.21 MB
# INFO:root:[series_pipe_95c4] : transforming x...
# INFO:root:[series_pipe_95c4] : -> column_renamer_3a21
# DEBUG:root:[column_renamer_3a21] : x new column names: ['x_00', 'x_01', 'x_02', 'x_03', 'x_04', 'x_05', 'x_06', 'x_07', 'x_08', 'x_09', 'x_10', 'x_11', 'x_12', 'x_13', 'x_14', 'x_15', 'x_16', 'x_17', 'x_18', 'x_19', 'x_20', 'x_21', 'x_22', 'x_23']
# INFO:root:[series_pipe_95c4] : -> drop_duplicates_eb03
# DEBUG:root:[drop_duplicates_eb03] : x shape: (19735, 24)
# DEBUG:root:[drop_duplicates_eb03] :   shape: (19735, 24)
# INFO:root:[series_pipe_95c4] : -> knn_imputer_f7a6
# DEBUG:root:[category2_number_28ac] : transforming...
# DEBUG:root:[category2_number_28ac] : x category to number: {}
# WARNING:root:[category2_number_28ac] : input is not a Pandas DataFrame, instead got <class 'NoneType'>
# DEBUG:root:[category2_number_28ac] : inverse transforming...
# DEBUG:root:[category2_number_28ac] : x number to category: {}
# WARNING:root:[category2_number_28ac] : input is not a Pandas DataFrame, instead got <class 'NoneType'>
# INFO:root:[series_pipe_95c4] : -> mad_scaler_68d
# INFO:root:[series_pipe_95c4] : -> unit_lenght_scaler_148
# INFO:root:[series_pipe_95c4] : -> to_numpy_4ab9
# INFO:root:[series_pipe_95c4] : -> lstm_packer_192e
# DEBUG:root:Function: transform_x: 5.53 sec
# DEBUG:root:Function: timed after Memory: 345.72 MB
# DEBUG:root:Function: timed before Memory: 345.72 MB
# INFO:root:[series_pipe_95c4] : transforming y...
# INFO:root:[series_pipe_95c4] : -> column_renamer_3a21
# DEBUG:root:[column_renamer_3a21] : y new column names: ['y_0']
# INFO:root:[series_pipe_95c4] : -> drop_duplicates_eb03
# DEBUG:root:[drop_duplicates_eb03] : y shape: (19735, 1)
# DEBUG:root:[drop_duplicates_eb03] :   shape: (19735, 1)
# INFO:root:[series_pipe_95c4] : -> knn_imputer_f7a6
# INFO:root:[series_pipe_95c4] : -> mad_scaler_68d
# INFO:root:[series_pipe_95c4] : -> unit_lenght_scaler_148
# INFO:root:[series_pipe_95c4] : -> to_numpy_4ab9
# INFO:root:[series_pipe_95c4] : -> lstm_packer_192e
# DEBUG:root:Function: transform_y: 0.02 sec
# DEBUG:root:Function: timed after Memory: 346.46 MB

# %%
x_new
# Out:
# array([[[-0.16423042,  0.2934058 , -0.05614959, ...,  0.2023891 ,
#           0.31778608,  0.06640165],
#         [-0.16880086,  0.26726139, -0.0577122 , ...,  0.18721932,
#           0.27219157,  0.06459335],
#         [-0.17272954,  0.25819465, -0.0590554 , ...,  0.17029038,
#           0.22282126,  0.06235537],
#         [-0.17566019,  0.25335294, -0.06005737, ...,  0.15153219,
#           0.16995135,  0.05960854],
#         [-0.1779208 ,  0.26728895, -0.06083027, ...,  0.13155625,
#           0.114759  ,  0.05652189]],
#
#        [[-0.16880086,  0.26726139, -0.0577122 , ...,  0.18721932,
#           0.27219157,  0.06459335],
#         [-0.17272954,  0.25819465, -0.0590554 , ...,  0.17029038,
#           0.22282126,  0.06235537],
#         [-0.17566019,  0.25335294, -0.06005737, ...,  0.15153219,
#           0.16995135,  0.05960854],
#         [-0.1779208 ,  0.26728895, -0.06083027, ...,  0.13155625,
#           0.114759  ,  0.05652189],
#         [-0.17955591,  0.25735566, -0.0613893 , ...,  0.11063772,
#           0.05790682,  0.05315215]],
#
#        [[-0.17272954,  0.25819465, -0.0590554 , ...,  0.17029038,
#           0.22282126,  0.06235537],
#         [-0.17566019,  0.25335294, -0.06005737, ...,  0.15153219,
#           0.16995135,  0.05960854],
#         [-0.1779208 ,  0.26728895, -0.06083027, ...,  0.13155625,
#           0.114759  ,  0.05652189],
#         [-0.17955591,  0.25735566, -0.0613893 , ...,  0.11063772,
#           0.05790682,  0.05315215],
#         [-0.18087549,  0.24866549, -0.06184046, ...,  0.08916065,
#           0.        ,  0.04962501]],
#
#        ...,
#        [[ 0.26631056,  0.20493167,  0.2994154 , ..., -0.03597439,
#          -0.1751886 ,  0.2512311 ],
#         [ 0.27388131,  0.19855115,  0.29865645, ..., -0.02885772,
#          -0.17730641,  0.25275919],
#         [ 0.27189733,  0.19158804,  0.30199461, ..., -0.02185069,
#          -0.17071815,  0.25432779],
#         [ 0.27823578,  0.18631028,  0.30192681, ..., -0.01478145,
#          -0.16482066,  0.25720363],
#         [ 0.27666925,  0.18679045,  0.29830824, ..., -0.00747474,
#          -0.15818945,  0.25925155]],
#
#        [[ 0.27388131,  0.19855115,  0.29865645, ..., -0.02885772,
#          -0.17730641,  0.25275919],
#         [ 0.27189733,  0.19158804,  0.30199461, ..., -0.02185069,
#          -0.17071815,  0.25432779],
#         [ 0.27823578,  0.18631028,  0.30192681, ..., -0.01478145,
#          -0.16482066,  0.25720363],
#         [ 0.27666925,  0.18679045,  0.29830824, ..., -0.00747474,
#          -0.15818945,  0.25925155],
#         [ 0.27848729,  0.19067376,  0.29372307, ...,  0.        ,
#          -0.15066825,  0.26007354]],
#
#        [[ 0.27189733,  0.19158804,  0.30199461, ..., -0.02185069,
#          -0.17071815,  0.25432779],
#         [ 0.27823578,  0.18631028,  0.30192681, ..., -0.01478145,
#          -0.16482066,  0.25720363],
#         [ 0.27666925,  0.18679045,  0.29830824, ..., -0.00747474,
#          -0.15818945,  0.25925155],
#         [ 0.27848729,  0.19067376,  0.29372307, ...,  0.        ,
#          -0.15066825,  0.26007354],
#         [ 0.28289653,  0.20467044,  0.28699899, ...,  0.00764298,
#          -0.14435751,  0.26329566]]])

# %%
y_new
# Out:
# array([[ 0.15980476],
#        [ 0.26634127],
#        [ 0.26634127],
#        ...,
#        [ 1.1719016 ],
#        [ 1.97092541],
#        [ 2.02419367]])

# %% [markdown]
# now your data is properly packed for Keras or TensorFlow LSTM ;-)
